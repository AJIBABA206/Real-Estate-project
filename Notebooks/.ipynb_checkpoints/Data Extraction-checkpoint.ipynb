# %% [markdown]
# # DATA EXTRACTION FROM PROPERTYPRO WEBSITES
#
#
# ##### EXTRACTING FOR 5060 PROPERTY

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
URL= f"https://propertypro.ng/property-for-sale?page={page_num}"

all_properties = []
# try and except is another keyword , that tries and if not it returns and it works like conditional statement.
def make_connection(url):
    ### makes connection##
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup_content = BeautifulSoup(response.content, "html.parser")
            print(f"Scrapping Property Data From Page {page_num} Below:")
            return soup_content
        else:
            print(f"Resources Not Available! status_code {response.status_code}")
    except Exception as e:
        print(f"An error occurred!. Mesage{e}")


def scrape_page_property(One_page_content):
    ##helps scrapping for just one page and it is loooped
    for property_content_div in One_page_content:
        property_title_div = property_content_div.find("div", class_= "pl-title").find('h3')
        property_title = property_title_div.get_text() if property_title_div is not None else "N/A"
        
        property_price_div = property_content_div.find("div", class_="pl-price").find('h3')
        property_price = property_price_div.get_text() if property_price_div is not None else "N/A"
        
        property_location_div = property_content_div.find("div", class_= "pl-title").find('p')
        property_location = property_location_div.get_text() if property_location_div is not None else "N/A"
        
        property_amenities_div = property_content_div.find("div", class_= "pl-price").find('h6')
        property_amenities = property_amenities_div.get_text() if property_amenities_div is not None else "N/A"
        
        property_type_div = property_content_div.find("div", class_= "pl-title").find('h6').find('a')
        property_type =  property_type_div.get_text() if  property_type_div is not None else "N/A"
        
        property_agent_div = property_content_div.find("div", class_= "flex-grow-1 ms-2")
        property_agent = property_agent_div.get_text() if property_agent_div is not None else "N/A"
        
        property_link_div =  property_content_div.find("div", class_= "pl-title").find('h6').find('a')
        property_link = property_link_div.get("href") if property_link_div is not None else "N/A"
        property_date_div = property_content_div.find("p", class_= "date-added")
        property_date = property_date_div.get_text() if property_date_div is not None else "N/A"

        
        single_property = {
        "Title": property_title,
        "Price": property_price,
        "Location": property_location,
        "Amenities": property_amenities,
        "Type": property_type,
        "Agent": property_agent,
        "Link": property_link,
        "Date":property_date
        }
    
        all_properties.append(single_property)
        ## appending the single page into the full all properties 
    print(f"PROPERTY SCRAPPED SUCCESFULLY: {len(One_page_content)} PROPERTIES RETRIEVED")
    return all_properties

# %%
#scrapping for 230 pages which is 5000 data
all_properties= []
# our new variable for all the content scrapped
for page_num in range(0,230):
    # gives the range of the sites to loop into
    
    #dynamic website URL
    URL= f"https://propertypro.ng/property-for-sale?page={page_num}"

    #making connection
    content = make_connection(url = URL)

    One_page_content = content.find_all("div", class_="property-listing-content")# all properties in a page


    #scrapping
    single_page_properties = scrape_page_property(One_page_content)
    

    # sleep
    time.sleep(5)
# Out:
# An error occurred!. MesageHTTPSConnectionPool(host='propertypro.ng', port=443): Max retries exceeded with url: /property-for-sale?page=0 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001AC3973A6F0>: Failed to resolve 'propertypro.ng' ([Errno 11002] getaddrinfo failed)"))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[250], line 13
#      10 #making connection
#      11 content = make_connection(url = URL)
# ---> 13 One_page_content = content.find_all("div", class_="property-listing-content")# all properties in a page
#      16 #scrapping
#      17 single_page_properties = scrape_page_property(One_page_content)
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
len(all_properties)
# Out:
# 5038

# %%
all_properties
# Out:
# [{'Title': ' Newly Built 4 Bedroom Duplex ',
#   'Price': ' ₦ 200,000,000 ',
#   'Location': 'Enugu Enugu',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Newly Built 4 Bedroom Duplex',
#   'Agent': '\n               Uchay properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-enugu-enugu-9NQTU',
#   'Date': 'Updated 31 Oct 2025, Added 07 Oct 2025'},
#  {'Title': ' 10 Plots Of Lands ',
#   'Price': '₦ 5,100,000',
#   'Location': 'Ngor Okpala/fortune Garden Estate/ 4min To Zion Ministry Ngor Okpala Imo',
#   'Amenities': ' ',
#   'Type': '10 Plots Of Lands',
#   'Agent': '\n               CHI REALTOR \n             ',
#   'Link': '/property/land-for-sale-ngor-okpala-fortune-garden-estate-4min-to-zion-ministry-ngor-okpala-imo-9NTJS',
#   'Date': ' Updated 01 Nov 2025, Added 01 Nov 2025'},
#  {'Title': ' 5 Bedroom Detached House ',
#   'Price': '₦ 2,250,000,000',
#   'Location': 'Old Ikoyi Ikoyi Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': '5 Bedroom Detached House',
#   'Agent': '\n               PRINCE ADEMOLA \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-old-ikoyi-ikoyi-lagos-2NMRX',
#   'Date': ' Updated 01 Nov 2025, Added 08 Sep 2025'},
#  {'Title': ' 6 Bedroom Detached House With 2 Bq ',
#   'Price': '₦ 2,000,000,000',
#   'Location': 'Old Ikoyi Old Ikoyi Ikoyi Lagos',
#   'Amenities': ' 6 Beds 6 Baths ',
#   'Type': '6 Bedroom Detached House With 2 Bq',
#   'Agent': '\n               PRINCE ADEMOLA \n             ',
#   'Link': '/property/6-bedroom-house-for-sale-old-ikoyi-old-ikoyi-ikoyi-lagos-6NMSZ',
#   'Date': ' Updated 01 Nov 2025, Added 09 Sep 2025'},
#  {'Title': ' 4 Bedroom Terrace House ',
#   'Price': '$ 1,145,000',
#   'Location': 'Banana Island Estate Banana Island Ikoyi Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Terrace House',
#   'Agent': '\n               PRINCE ADEMOLA \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-banana-island-estate-banana-island-ikoyi-lagos-1NPGU',
#   'Date': ' Updated 01 Nov 2025, Added 24 Sep 2025'},
#  {'Title': ' Luxury 5bedroom Fully Detached Duplex ',
#   'Price': '₦ 700,000,000',
#   'Location': 'Ikate Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': 'Luxury 5bedroom Fully Detached Duplex',
#   'Agent': "\n               TORY'S REALTY \n             ",
#   'Link': '/property/5-bedroom-house-for-sale-ikate-lekki-phase-1-lekki-lagos-5NTJP',
#   'Date': ' Added 01 Nov 2025'},
#  {'Title': ' 6 Bedroom Smart Home ',
#   'Price': '₦ 390,000,000',
#   'Location': 'Chevron Drive Chevron Lekki Lagos',
#   'Amenities': ' 6 Beds 6 Baths ',
#   'Type': '6 Bedroom Smart Home',
#   'Agent': '\n               PECONS REALTORS \n             ',
#   'Link': '/property/6-bedroom-house-for-sale-chevron-drive-chevron-lekki-lagos-9NTJL',
#   'Date': ' Updated 01 Nov 2025, Added 01 Nov 2025'},
#  {'Title': ' Luxury 5 Bedroom Detached Duplex With Boys Quarter ',
#   'Price': '₦ 220,000,000',
#   'Location': 'Ado Ajah Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': 'Luxury 5 Bedroom Detached Duplex With Boys Quarter',
#   'Agent': '\n               Shelter Nest \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-ado-ajah-lagos-0NTEQ',
#   'Date': ' Updated 01 Nov 2025, Added 30 Oct 2025'},
#  {'Title': ' Contemporary 4 Bedroom Fully Detached Duplex ',
#   'Price': '₦ 200,000,000',
#   'Location': 'Ajah Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Contemporary 4 Bedroom Fully Detached Duplex',
#   'Agent': '\n               Perfect Images \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ajah-lekki-lagos-3NTJF',
#   'Date': ' Updated 01 Nov 2025, Added 01 Nov 2025'},
#  {'Title': ' Newly Built 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 150,000,000',
#   'Location': 'Ajah Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Newly Built 4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               Perfect Images \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ajah-lekki-lagos-2NTJE',
#   'Date': ' Updated 01 Nov 2025, Added 01 Nov 2025'},
#  {'Title': ' Stunning 5 Bedroom Detached Duplex ',
#   'Price': ' ₦ 600,000,000 ',
#   'Location': 'Chevron Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': 'Stunning 5 Bedroom Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-chevron-lekki-lagos-1NQXC',
#   'Date': 'Updated 31 Oct 2025, Added 08 Oct 2025'},
#  {'Title': ' Newly Built 2 Bedroom Terrace Duplex ',
#   'Price': '₦ 95,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': 'Newly Built 2 Bedroom Terrace Duplex',
#   'Agent': '\n               ADULLAM REALTY \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-orchid-lekki-lagos-4NTCB',
#   'Date': ' Updated 01 Nov 2025, Added 29 Oct 2025'},
#  {'Title': ' 3 Bedroom Terrace Duplex With Bq ',
#   'Price': '₦ 80,000,000',
#   'Location': 'Ajah Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': '3 Bedroom Terrace Duplex With Bq',
#   'Agent': '\n               Freddie Homes \n             ',
#   'Link': '/property/3-bedroom-house-for-sale-ajah-lagos-4NDYS',
#   'Date': ' Updated 01 Nov 2025, Added 01 Jul 2025'},
#  {'Title': ' Spacious 4 Bedroom Semi’s Detached Duplex ',
#   'Price': '₦ 150,000,000',
#   'Location': 'Ajah Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Spacious 4 Bedroom Semi’s Detached Duplex',
#   'Agent': '\n               Perfect Images \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ajah-lekki-lagos-3NTHZ',
#   'Date': ' Updated 01 Nov 2025, Added 01 Nov 2025'},
#  {'Title': ' Luxury 4 Bedroom Terrace Duplex With Bq +inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Berger Clinic Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Luxury 4 Bedroom Terrace Duplex With Bq +inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-berger-clinic-life-camp-abuja-0NPME',
#   'Date': ' Updated 01 Nov 2025, Added 25 Sep 2025'},
#  {'Title': ' Smart Luxury 4 Bedroom Terrace Duplex With Bq+inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Fct Minster’s House Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Smart Luxury 4 Bedroom Terrace Duplex With Bq+inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-fct-minsters-house-life-camp-abuja-1NPMF',
#   'Date': ' Updated 01 Nov 2025, Added 25 Sep 2025'},
#  {'Title': ' Automated 4 Bedroom Terrace Duplex With Bq ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Berger Clinic Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Automated 4 Bedroom Terrace Duplex With Bq',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-berger-clinic-life-camp-abuja-9NPNF',
#   'Date': ' Updated 01 Nov 2025, Added 26 Sep 2025'},
#  {'Title': ' Automated 4 Bedroom Terrace Duplex With Bq + Inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Fct Minister’s House Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Automated 4 Bedroom Terrace Duplex With Bq + Inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-fct-ministers-house-life-camp-abuja-0NPNR',
#   'Date': ' Updated 01 Nov 2025, Added 26 Sep 2025'},
#  {'Title': ' Luxury 4 Bedroom Terrace Duplex With Bq + Inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Berger Clinic Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Luxury 4 Bedroom Terrace Duplex With Bq + Inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-berger-clinic-life-camp-abuja-6NPRL',
#   'Date': ' Updated 01 Nov 2025, Added 27 Sep 2025'},
#  {'Title': ' Luxury 4 Bedroom Terraced Duplex With Bq/inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Old Aprofim Estate, Berger Clinic, Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Luxury 4 Bedroom Terraced Duplex With Bq/inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-old-aprofim-estate-berger-clinic-life-camp-abuja-5NQMC',
#   'Date': ' Updated 01 Nov 2025, Added 05 Oct 2025'},
#  {'Title': ' Automated 4 Bedroom Terraced Duplex With Bq ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Old Aprofim Estate, Berger Clinic, Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Automated 4 Bedroom Terraced Duplex With Bq',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-old-aprofim-estate-berger-clinic-life-camp-abuja-8NQMC',
#   'Date': ' Updated 01 Nov 2025, Added 05 Oct 2025'},
#  {'Title': ' Luxury Furnished 4 Bedroom Semi Detached Duplex With Bq ',
#   'Price': '₦ 180,000,000',
#   'Location': 'Belham Estate By Efab Bridge, Gwarimpa Extension, Karsana Abuja',
#   'Amenities': ' 4 Beds 5 Baths ',
#   'Type': 'Luxury Furnished 4 Bedroom Semi Detached Duplex With Bq',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-belham-estate-by-efab-bridge-gwarimpa-extension-karsana-abuja-0NQMD',
#   'Date': ' Updated 01 Nov 2025, Added 05 Oct 2025'},
#  {'Title': ' 160 Rooms ',
#   'Price': ' ₦ 15,000,000,000 ',
#   'Location': 'Airport By Presidential Wing Lugbe Abuja',
#   'Amenities': ' ',
#   'Type': '160 Rooms',
#   'Agent': '\n               Shedrack Luka \n             ',
#   'Link': '/property/commercial-property-for-sale-airport-by-presidential-wing-lugbe-abuja-3NPBC',
#   'Date': 'Updated 31 Oct 2025, Added 22 Sep 2025'},
#  {'Title': ' Automated 4 Bedroom Terrace Duplex + Bq ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Berger Clinic/fct Minister’s House Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Automated 4 Bedroom Terrace Duplex + Bq',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-berger-clinic-fct-ministers-house-life-camp-abuja-0NQXT',
#   'Date': ' Updated 01 Nov 2025, Added 09 Oct 2025'},
#  {'Title': ' Automated 4 Bedroom Terrace Duplex + Bq ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Berger Clinic/fct Minister’s House Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Automated 4 Bedroom Terrace Duplex + Bq',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-berger-clinic-fct-ministers-house-life-camp-abuja-5NQXT',
#   'Date': ' Updated 01 Nov 2025, Added 09 Oct 2025'},
#  {'Title': ' Luxury 4 Bedroom Terrace Duplex & Bq +inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Berger Clinic/fct Minister’s House Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Luxury 4 Bedroom Terrace Duplex & Bq +inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-berger-clinic-fct-ministers-house-life-camp-abuja-4NQXV',
#   'Date': ' Updated 01 Nov 2025, Added 09 Oct 2025'},
#  {'Title': ' Automated 4 Bedroom Duplex +bq & Inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Fct Minister’s House Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Automated 4 Bedroom Duplex +bq & Inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-fct-ministers-house-life-camp-abuja-3NQXW',
#   'Date': ' Updated 01 Nov 2025, Added 09 Oct 2025'},
#  {'Title': ' Smart Luxury 4 Bedroom Terrace Duplex +bq & Inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Berger Clinic/fct Minister’s House Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Smart Luxury 4 Bedroom Terrace Duplex +bq & Inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-berger-clinic-fct-ministers-house-life-camp-abuja-3NQXZ',
#   'Date': ' Updated 01 Nov 2025, Added 09 Oct 2025'},
#  {'Title': ' Luxury 4 Bedroom Terrace Duplex +bq & Inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Berger Clinic/fct Minister’s House Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Luxury 4 Bedroom Terrace Duplex +bq & Inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-berger-clinic-fct-ministers-house-life-camp-abuja-7NQXZ',
#   'Date': ' Updated 01 Nov 2025, Added 09 Oct 2025'},
#  {'Title': ' Luxury 4 Bedroom Terrace Duplex With Bq & Inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Berger Clinic/ Fct Minister’s House Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Luxury 4 Bedroom Terrace Duplex With Bq & Inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-berger-clinic-fct-ministers-house-life-camp-abuja-3NQYA',
#   'Date': ' Updated 01 Nov 2025, Added 09 Oct 2025'},
#  {'Title': ' Automated 4 Bedroom Terrace Duplex With Bq & Inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Berger Clinic/fct Minister’s House Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Automated 4 Bedroom Terrace Duplex With Bq & Inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-berger-clinic-fct-ministers-house-life-camp-abuja-2NQYB',
#   'Date': ' Updated 01 Nov 2025, Added 09 Oct 2025'},
#  {'Title': ' Luxury 4 Bedroom Terrace Duplex With Bq & Inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Berger Clinic/fct Minister’s House Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Luxury 4 Bedroom Terrace Duplex With Bq & Inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-berger-clinic-fct-ministers-house-life-camp-abuja-9NQYB',
#   'Date': ' Updated 01 Nov 2025, Added 09 Oct 2025'},
#  {'Title': ' Modern 3 Bedroom Apartment With Bq ',
#   'Price': ' ₦ 265,000,000 ',
#   'Location': 'Adeniyi Jones Ikeja Lagos',
#   'Amenities': ' 3 Beds ',
#   'Type': 'Modern 3 Bedroom Apartment With Bq',
#   'Agent': '\n               PMNG Acquisitions \n             ',
#   'Link': '/property/3-bedroom-flat-apartment-for-sale-adeniyi-jones-ikeja-lagos-0NRTM',
#   'Date': 'Updated 31 Oct 2025, Added 16 Oct 2025'},
#  {'Title': ' Automated 4 Bedroom Terrace Duplex +bq &inverter ',
#   'Price': '₦ 150,000,000',
#   'Location': 'By Fct Minister’s House/ Berger Clinic Life Camp Abuja',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': 'Automated 4 Bedroom Terrace Duplex +bq &inverter',
#   'Agent': '\n               BEVIKS REALTY \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-by-fct-ministers-house-berger-clinic-life-camp-abuja-7NQYC',
#   'Date': ' Updated 01 Nov 2025, Added 09 Oct 2025'},
#  {'Title': ' Available In 300,500&1000sqm ',
#   'Price': '₦ 15,000,000',
#   'Location': 'Eleranigbe/ *ajé Gardens Estate / Along Lekki Epe Expressway Pan Atlantic University Eleranigbe Ibeju Lekki Lagos',
#   'Amenities': ' ',
#   'Type': 'Available In 300,500&1000sqm',
#   'Agent': '\n               CHI REALTOR \n             ',
#   'Link': '/property/land-for-sale-eleranigbe-aje-gardens-estate-along-lekki-epe-expressway-pan-atlantic-university-eleranigbe-ibeju-lekki-lagos-2NTHW',
#   'Date': ' Updated 01 Nov 2025, Added 01 Nov 2025'},
#  {'Title': ' Newly Built Bungalow With Pool ',
#   'Price': '₦ 68,000,000',
#   'Location': 'Eleranigbe Ibeju Lekki Lagos',
#   'Amenities': ' ',
#   'Type': 'Newly Built Bungalow With Pool',
#   'Agent': '\n               CHI REALTOR \n             ',
#   'Link': '/property/house-for-sale-eleranigbe-ibeju-lekki-lagos-2NSBU',
#   'Date': ' Updated 01 Nov 2025, Added 20 Oct 2025'},
#  {'Title': ' Newly Built 2 Bedroom Apartment ',
#   'Price': '₦ 200,000,000',
#   'Location': 'Ikate Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': 'Newly Built 2 Bedroom Apartment',
#   'Agent': '\n               Oyewo Abiola \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-ikate-lekki-lagos-8NRSP',
#   'Date': ' Updated 31 Oct 2025, Added 16 Oct 2025'},
#  {'Title': ' Sharp 4 Bedroom Terrace Duplex With A Bq In Ikate ',
#   'Price': '₦ 260,000,000',
#   'Location': 'Ikate Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Sharp 4 Bedroom Terrace Duplex With A Bq In Ikate',
#   'Agent': '\n               Oyewo Abiola \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ikate-lekki-lagos-8NTHQ',
#   'Date': ' Updated 31 Oct 2025, Added 31 Oct 2025'},
#  {'Title': ' Newly Built 4 Bedroom Duplex ',
#   'Price': '₦ 200,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Newly Built 4 Bedroom Duplex',
#   'Agent': '\n               Oyewo Abiola \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-2NRSF',
#   'Date': ' Updated 31 Oct 2025, Added 16 Oct 2025'},
#  {'Title': ' Fully Functioning 18 Rooms Hotel ',
#   'Price': '₦ 680,000,000',
#   'Location': 'Alausa Ikeja Lagos',
#   'Amenities': ' 10 Beds 10 Baths ',
#   'Type': 'Fully Functioning 18 Rooms Hotel',
#   'Agent': '\n               Oyewo Abiola \n             ',
#   'Link': '/property/10-bedroom-commercial-property-for-sale-alausa-ikeja-lagos-7NQLX',
#   'Date': ' Updated 31 Oct 2025, Added 05 Oct 2025'},
#  {'Title': ' New 5 Bedroom Fully Detached Duplex ',
#   'Price': '₦ 350,000,000',
#   'Location': 'Chevron Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': 'New 5 Bedroom Fully Detached Duplex',
#   'Agent': '\n               Oyewo Abiola \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-chevron-lekki-lagos-0NQNK',
#   'Date': ' Updated 31 Oct 2025, Added 06 Oct 2025'},
#  {'Title': ' 11 Bedroom House With Rooftop Terraced ',
#   'Price': '₦ 800,000,000',
#   'Location': 'Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 10 Beds 10 Baths ',
#   'Type': '11 Bedroom House With Rooftop Terraced',
#   'Agent': '\n               Oyewo Abiola \n             ',
#   'Link': '/property/10-bedroom-commercial-property-for-sale-lekki-phase-1-lekki-lagos-3NRRH',
#   'Date': ' Updated 31 Oct 2025, Added 15 Oct 2025'},
#  {'Title': ' 18 Room Fully Functioning Hotel In Ikeja, Lagos ',
#   'Price': '₦ 680,000,000',
#   'Location': 'Alausa Ikeja Lagos',
#   'Amenities': ' 10 Beds 10 Baths ',
#   'Type': '18 Room Fully Functioning Hotel In Ikeja, Lagos',
#   'Agent': '\n               Oyewo Abiola \n             ',
#   'Link': '/property/10-bedroom-commercial-property-for-sale-alausa-ikeja-lagos-9NPWQ',
#   'Date': ' Updated 31 Oct 2025, Added 29 Sep 2025'},
#  {'Title': ' 1400sqms Of Land ',
#   'Price': '₦ 1,600,000,000',
#   'Location': 'Jibowu Yaba Lagos',
#   'Amenities': ' ',
#   'Type': '1400sqms Of Land',
#   'Agent': '\n               Oyewo Abiola \n             ',
#   'Link': '/property/commercial-property-for-sale-jibowu-yaba-lagos-3NRXJ',
#   'Date': ' Updated 31 Oct 2025, Added 17 Oct 2025'},
#  {'Title': ' 4 Bedroom Detached Duplex With Bq ',
#   'Price': ' ₦ 210,000,000 ',
#   'Location': 'Carlton Gate Estate, Lagelu Oyo',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Detached Duplex With Bq',
#   'Agent': '\n               Maxwellproperties \n             ',
#   'Link': '/property/4-bedroom-flat-apartment-for-sale-carlton-gate-estate-lagelu-oyo-4NQNG',
#   'Date': 'Updated 31 Oct 2025, Added 06 Oct 2025'},
#  {'Title': ' 5 Bedroom Fully Detached Duplex ',
#   'Price': '₦ 980,000,000',
#   'Location': 'Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': '5 Bedroom Fully Detached Duplex',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-lekki-phase-1-lekki-lagos-7NRTC',
#   'Date': ' Updated 31 Oct 2025, Added 16 Oct 2025'},
#  {'Title': ' 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 155,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-5NTBW',
#   'Date': ' Updated 31 Oct 2025, Added 29 Oct 2025'},
#  {'Title': ' 4 Bedroom Fully Detached Smart Home ',
#   'Price': '₦ 200,000,000',
#   'Location': 'Lekki Phase 2 Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Fully Detached Smart Home',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-lekki-phase-2-lekki-lagos-7NRTJ',
#   'Date': ' Updated 31 Oct 2025, Added 16 Oct 2025'},
#  {'Title': ' Serviced 3 Bedroom Terrace Duplex ',
#   'Price': '₦ 90,000,000',
#   'Location': 'Abraham Adesanya Lekki Phase 2 Lekki Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': 'Serviced 3 Bedroom Terrace Duplex',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/3-bedroom-house-for-sale-abraham-adesanya-lekki-phase-2-lekki-lagos-4NTBX',
#   'Date': ' Updated 31 Oct 2025, Added 29 Oct 2025'},
#  {'Title': ' Tastefully Built 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 145,000,000',
#   'Location': 'Abraham Adesanya, Lekki Phase 2 Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Tastefully Built 4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-abraham-adesanya-lekki-phase-2-lekki-lagos-9NSBS',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  {'Title': ' 2 Bedroom Apartment ',
#   'Price': '₦ 95,000,000',
#   'Location': 'Ologolo Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': '2 Bedroom Apartment',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-ologolo-lekki-lagos-3NRPN',
#   'Date': ' Updated 31 Oct 2025, Added 15 Oct 2025'},
#  {'Title': ' Luxury 2 Bedroom Apartment With Swimming Pool ',
#   'Price': '₦ 85,000,000',
#   'Location': 'Chevron Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': 'Luxury 2 Bedroom Apartment With Swimming Pool',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-chevron-lekki-lagos-7NQWT',
#   'Date': ' Updated 31 Oct 2025, Added 08 Oct 2025'},
#  {'Title': ' Modern 2 Bedroom Apartment With Bq ',
#   'Price': '₦ 68,000,000',
#   'Location': 'Ajah Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': 'Modern 2 Bedroom Apartment With Bq',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-ajah-lagos-6NSCP',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  {'Title': ' Ultra Luxury 5 Bedroom Smart Home ',
#   'Price': '₦ 1,000,000,000',
#   'Location': 'Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': 'Ultra Luxury 5 Bedroom Smart Home',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-lekki-phase-1-lekki-lagos-5NRTS',
#   'Date': ' Updated 31 Oct 2025, Added 16 Oct 2025'},
#  {'Title': ' 3 Bedroom Apartment ',
#   'Price': ' ₦ 150,000/day ',
#   'Location': 'Jericho Gra Ibadan Oyo',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': '3 Bedroom Apartment',
#   'Agent': '\n               Poly property \n             ',
#   'Link': '/property/3-bedroom-flat-apartment-for-shortlet-jericho-gra-ibadan-oyo-6NSMP',
#   'Date': 'Updated 31 Oct 2025, Added 23 Oct 2025'},
#  {'Title': ' Contemporary 4 Bedroom Semi Detached Duplex With Bq ',
#   'Price': '₦ 178,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Contemporary 4 Bedroom Semi Detached Duplex With Bq',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-8NSWH',
#   'Date': ' Updated 31 Oct 2025, Added 27 Oct 2025'},
#  {'Title': ' Contemporary 2 Bedroom Apartment ',
#   'Price': '₦ 75,000,000',
#   'Location': 'Abraham Adesanya, Lekki Phase 2 Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': 'Contemporary 2 Bedroom Apartment',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-abraham-adesanya-lekki-phase-2-lekki-lagos-7NSBQ',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  {'Title': ' Serviced 1 Bedroom Apartment ',
#   'Price': '₦ 65,000,000',
#   'Location': 'Ologolo Lekki Lagos',
#   'Amenities': ' 1 Beds 1 Baths ',
#   'Type': 'Serviced 1 Bedroom Apartment',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/1-bedroom-flat-apartment-for-sale-ologolo-lekki-lagos-3NQYS',
#   'Date': ' Updated 31 Oct 2025, Added 09 Oct 2025'},
#  {'Title': ' 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 300,000,000',
#   'Location': 'Ologolo Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ologolo-lekki-lagos-6NSNX',
#   'Date': ' Updated 31 Oct 2025, Added 23 Oct 2025'},
#  {'Title': ' 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 290,000,000',
#   'Location': 'Ologolo Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ologolo-lekki-lagos-8NSLJ',
#   'Date': ' Updated 31 Oct 2025, Added 22 Oct 2025'},
#  {'Title': ' Automated 5 Bedroom Semi Detached Duplex With Bq ',
#   'Price': '₦ 275,000,000',
#   'Location': 'Osapa London Lekki Lagos',
#   'Amenities': ' 5 Beds 4 Baths ',
#   'Type': 'Automated 5 Bedroom Semi Detached Duplex With Bq',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-osapa-london-lekki-lagos-8NSNY',
#   'Date': ' Updated 31 Oct 2025, Added 23 Oct 2025'},
#  {'Title': ' 4 Bedroom Fully Detached Duplex ',
#   'Price': '₦ 140,000,000',
#   'Location': 'Lekki Phase 2 Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Fully Detached Duplex',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-lekki-phase-2-lekki-lagos-3NSPA',
#   'Date': ' Updated 31 Oct 2025, Added 23 Oct 2025'},
#  {'Title': ' 4 Bedroom Semi Detached Duplex With Bq ',
#   'Price': '₦ 150,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Semi Detached Duplex With Bq',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-1NSYS',
#   'Date': ' Updated 31 Oct 2025, Added 28 Oct 2025'},
#  {'Title': ' 1 Bedroom Apartment ',
#   'Price': '₦ 50,000,000',
#   'Location': 'Ikota Lekki Lagos',
#   'Amenities': ' 1 Beds 1 Baths ',
#   'Type': '1 Bedroom Apartment',
#   'Agent': '\n               Laprenge Properties \n             ',
#   'Link': '/property/1-bedroom-flat-apartment-for-sale-ikota-lekki-lagos-5NSCT',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  {'Title': ' Luxury Redefined! 4bedroom Detached Duplex ',
#   'Price': '₦ 380,000,000',
#   'Location': 'Kay Farm Estate Ifako Ogba Ogba Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Luxury Redefined! 4bedroom Detached Duplex',
#   'Agent': '\n               Safehouse Properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-kay-farm-estate-ifako-ogba-ogba-lagos-5NTHF',
#   'Date': ' Updated 31 Oct 2025, Added 31 Oct 2025'},
#  {'Title': ' Modern Luxurious Brand New 4 Bedroom Detached Duplex ',
#   'Price': '₦ 150,000,000',
#   'Location': 'Abule Egba Abule Egba Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Modern Luxurious Brand New 4 Bedroom Detached Duplex',
#   'Agent': '\n               Safehouse Properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-abule-egba-abule-egba-lagos-0NTGN',
#   'Date': ' Updated 31 Oct 2025, Added 31 Oct 2025'},
#  {'Title': ' 6 Bedroom Detached Duplex With Basement ',
#   'Price': ' ₦ 1,100,000,000 ',
#   'Location': 'By Coza Church Guzape Abuja',
#   'Amenities': ' 6 Beds 6 Baths ',
#   'Type': '6 Bedroom Detached Duplex With Basement',
#   'Agent': '\n               Innerowrkings investments \n             ',
#   'Link': '/property/6-bedroom-house-for-sale-by-coza-church-guzape-abuja-4NSLR',
#   'Date': 'Updated 31 Oct 2025, Added 23 Oct 2025'},
#  {'Title': ' Brand New 3bedroom Luxurious Apartments ',
#   'Price': '₦ 140,000,000',
#   'Location': 'Awuse Estate Opebi Ikeja Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': 'Brand New 3bedroom Luxurious Apartments',
#   'Agent': '\n               Safehouse Properties \n             ',
#   'Link': '/property/3-bedroom-flat-apartment-for-sale-awuse-estate-opebi-ikeja-lagos-9NTHG',
#   'Date': ' Updated 31 Oct 2025, Added 31 Oct 2025'},
#  {'Title': ' Superb Location! 4bedroom Terrace Duplex In Ikeja ',
#   'Price': '₦ 300,000,000',
#   'Location': 'Lagoon Awolowo Way Ikeja Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Superb Location! 4bedroom Terrace Duplex In Ikeja',
#   'Agent': '\n               Safehouse Properties \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-lagoon-awolowo-way-ikeja-lagos-0NTHG',
#   'Date': ' Updated 31 Oct 2025, Added 31 Oct 2025'},
#  {'Title': ' 5 Bedroom Semi Detached House ',
#   'Price': '₦ 900,000,000',
#   'Location': 'Ikate Lekki Lagos',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': '5 Bedroom Semi Detached House',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-ikate-lekki-lagos-4NPHA',
#   'Date': ' Updated 31 Oct 2025, Added 24 Sep 2025'},
#  {'Title': ' 5 Bedroom Fully Detached Duplex ',
#   'Price': '₦ 980,000,000',
#   'Location': 'Ikate Lekki Lagos',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': '5 Bedroom Fully Detached Duplex',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-ikate-lekki-lagos-4NQZF',
#   'Date': ' Updated 31 Oct 2025, Added 09 Oct 2025'},
#  {'Title': ' 1 Bedroom Apartment ',
#   'Price': '₦ 130,000,000',
#   'Location': 'Victoria Island Lagos',
#   'Amenities': ' 1 Beds 2 Baths ',
#   'Type': '1 Bedroom Apartment',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/1-bedroom-flat-apartment-for-sale-victoria-island-lagos-8NPHD',
#   'Date': ' Updated 31 Oct 2025, Added 24 Sep 2025'},
#  {'Title': ' 4 Bedroom Penthouse With Bq ',
#   'Price': '₦ 1,000,000,000',
#   'Location': 'Victoria Island Lagos',
#   'Amenities': ' 4 Beds 5 Baths ',
#   'Type': '4 Bedroom Penthouse With Bq',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/4-bedroom-flat-apartment-for-sale-victoria-island-lagos-1NQZF',
#   'Date': ' Updated 31 Oct 2025, Added 09 Oct 2025'},
#  {'Title': ' 5 Bedroom Fully Detached Duplex With Bq ',
#   'Price': '₦ 420,000,000',
#   'Location': 'Ikota Lekki Lagos',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': '5 Bedroom Fully Detached Duplex With Bq',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-ikota-lekki-lagos-1NQZH',
#   'Date': ' Updated 31 Oct 2025, Added 09 Oct 2025'},
#  {'Title': ' 5 Bedroom Terraced Duplex With Pool/gym ',
#   'Price': '₦ 1,400,000,000',
#   'Location': 'Ikoyi Lagos',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': '5 Bedroom Terraced Duplex With Pool/gym',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-ikoyi-lagos-4NSFX',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' 5 Bedroom Fully Detached Duplex With Bq ',
#   'Price': '₦ 2,300,000,000',
#   'Location': 'Ikoyi Lagos',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': '5 Bedroom Fully Detached Duplex With Bq',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-ikoyi-lagos-1NSFZ',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' Office ',
#   'Price': ' ₦ 750,000,000 ',
#   'Location': 'Toyin Street Ikeja Lagos',
#   'Amenities': ' ',
#   'Type': 'Office',
#   'Agent': '\n               Loyalty homes \n             ',
#   'Link': '/property/commercial-property-for-sale-toyin-street-ikeja-lagos-5MXVM',
#   'Date': 'Updated 31 Oct 2025, Added 14 May 2025'},
#  {'Title': ' 2 Bedroom Apartment ',
#   'Price': '₦ 295,000,000',
#   'Location': 'Oniru Victoria Island Lagos',
#   'Amenities': ' 2 Beds 3 Baths ',
#   'Type': '2 Bedroom Apartment',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/2-bedroom-flat-apartment-for-sale-oniru-victoria-island-lagos-6NSFZ',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' 5 Bedroom Fully Detached Duplex ',
#   'Price': '₦ 1,300,000,000',
#   'Location': 'Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': '5 Bedroom Fully Detached Duplex',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-lekki-phase-1-lekki-lagos-0NPPN',
#   'Date': ' Updated 31 Oct 2025, Added 26 Sep 2025'},
#  {'Title': ' Newly Built 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 260,000,000',
#   'Location': 'Chevron Lekki Lagos',
#   'Amenities': ' 4 Beds 5 Baths ',
#   'Type': 'Newly Built 4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-chevron-lekki-lagos-9NQZF',
#   'Date': ' Updated 31 Oct 2025, Added 09 Oct 2025'},
#  {'Title': ' 5 Bedroom Detached Duplex ',
#   'Price': '₦ 500,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 5 Beds 6 Baths ',
#   'Type': '5 Bedroom Detached Duplex',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-orchid-lekki-lagos-8NPGZ',
#   'Date': ' Updated 31 Oct 2025, Added 24 Sep 2025'},
#  {'Title': ' Contemporary 6 Bedroom Detached Duplex ',
#   'Price': '₦ 750,000,000',
#   'Location': 'Chevron Lekki Lagos',
#   'Amenities': ' 6 Beds 7 Baths ',
#   'Type': 'Contemporary 6 Bedroom Detached Duplex',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/6-bedroom-house-for-sale-chevron-lekki-lagos-6NPPM',
#   'Date': ' Updated 31 Oct 2025, Added 26 Sep 2025'},
#  {'Title': ' 2 Bedroom Apartment ',
#   'Price': '₦ 200,000,000',
#   'Location': 'Victoria Island Lagos',
#   'Amenities': ' 2 Beds 3 Baths ',
#   'Type': '2 Bedroom Apartment',
#   'Agent': '\n               Joe Etoniru \n             ',
#   'Link': '/property/2-bedroom-flat-apartment-for-sale-victoria-island-lagos-1NPHE',
#   'Date': ' Updated 31 Oct 2025, Added 24 Sep 2025'},
#  {'Title': ' Stunning 5 Bedroom Detached Duplex ',
#   'Price': '₦ 270,000,000',
#   'Location': 'Ikota Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': 'Stunning 5 Bedroom Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-ikota-lekki-lagos-0NRFN',
#   'Date': ' Updated 31 Oct 2025, Added 12 Oct 2025'},
#  {'Title': ' 2 Bedroom Apartment ',
#   'Price': '₦ 110,000,000',
#   'Location': 'Chevron Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': '2 Bedroom Apartment',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-chevron-lekki-lagos-3NSND',
#   'Date': ' Updated 31 Oct 2025, Added 23 Oct 2025'},
#  {'Title': ' Lovely 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 180,000,000',
#   'Location': 'Ikota Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Lovely 4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ikota-lekki-lagos-2NRFY',
#   'Date': ' Updated 31 Oct 2025, Added 12 Oct 2025'},
#  {'Title': ' Lovely 2 Bedroom Apartment ',
#   'Price': '₦ 200,000,000',
#   'Location': 'Ikate Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': 'Lovely 2 Bedroom Apartment',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-ikate-lekki-lagos-3NSAE',
#   'Date': ' Updated 31 Oct 2025, Added 19 Oct 2025'},
#  {'Title': ' 2 Bedroom Apartment ',
#   'Price': '₦ 260,000,000',
#   'Location': 'Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': '2 Bedroom Apartment',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-lekki-phase-1-lekki-lagos-6NSEH',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' 1000sqm Virgin Land ',
#   'Price': ' ₦ 580,000,000 ',
#   'Location': 'Orange Island Phase 2 Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' ',
#   'Type': '1000sqm Virgin Land',
#   'Agent': '\n               First Colony \n             ',
#   'Link': '/property/land-for-sale-orange-island-phase-2-lekki-phase-1-lekki-lagos-2NGLN',
#   'Date': 'Updated 31 Oct 2025, Added 22 Jul 2025'},
#  {'Title': ' Lovely 3 Bedroom Apartment ',
#   'Price': '₦ 180,000,000',
#   'Location': 'Ikate Lekki Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': 'Lovely 3 Bedroom Apartment',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/3-bedroom-house-for-sale-ikate-lekki-lagos-8NSCK',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  {'Title': ' Stunning 5 Bedroom Detached Duplex ',
#   'Price': '₦ 500,000,000',
#   'Location': 'Chevron Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': 'Stunning 5 Bedroom Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-chevron-lekki-lagos-5NSCL',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  {'Title': ' Lovely 3 Bedroom Apartment ',
#   'Price': '₦ 350,000,000',
#   'Location': 'Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': 'Lovely 3 Bedroom Apartment',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/3-bedroom-house-for-sale-lekki-phase-1-lekki-lagos-4NSAL',
#   'Date': ' Updated 31 Oct 2025, Added 19 Oct 2025'},
#  {'Title': ' 4 Bedroom Fully Detached Duplex With Bq ',
#   'Price': '₦ 250,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Fully Detached Duplex With Bq',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-9NSFR',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' Lovely 2 Bedroom Apartment ',
#   'Price': '₦ 82,000,000',
#   'Location': 'Chevron Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': 'Lovely 2 Bedroom Apartment',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-chevron-lekki-lagos-0NSED',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' Contemporary 4 Bedroom Detached Duplex ',
#   'Price': '₦ 180,000,000',
#   'Location': 'Ajah Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Contemporary 4 Bedroom Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ajah-lagos-7NRNH',
#   'Date': ' Updated 31 Oct 2025, Added 14 Oct 2025'},
#  {'Title': ' 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 200,000,000',
#   'Location': 'Ologolo Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ologolo-lekki-lagos-4NSNN',
#   'Date': ' Updated 31 Oct 2025, Added 23 Oct 2025'},
#  {'Title': ' Stunning 5 Bedroom Detached Duplex ',
#   'Price': '₦ 1,700,000,000',
#   'Location': 'Ikoyi Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': 'Stunning 5 Bedroom Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-ikoyi-lagos-5NSAK',
#   'Date': ' Updated 31 Oct 2025, Added 19 Oct 2025'},
#  {'Title': ' 4 Bedroom Terrace Duplex ',
#   'Price': '₦ 140,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Terrace Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-6NSNB',
#   'Date': ' Updated 31 Oct 2025, Added 23 Oct 2025'},
#  {'Title': ' 4 Bedroom Fully Detached Duplex ',
#   'Price': ' ₦ 180,000,000 ',
#   'Location': 'Ajah Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Fully Detached Duplex',
#   'Agent': '\n               Mongeorge limited \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ajah-lagos-0NSLS',
#   'Date': 'Updated 31 Oct 2025, Added 23 Oct 2025'},
#  {'Title': ' 3 Bedroom Apartment ',
#   'Price': '₦ 200,000,000',
#   'Location': 'Ikate Lekki Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': '3 Bedroom Apartment',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/3-bedroom-house-for-sale-ikate-lekki-lagos-8NSNT',
#   'Date': ' Updated 31 Oct 2025, Added 23 Oct 2025'},
#  {'Title': ' Luxury 4 Bedroom Terraced Duplex ',
#   'Price': '₦ 900,000,000',
#   'Location': 'Ikoyi Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Luxury 4 Bedroom Terraced Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ikoyi-lagos-7NRQF',
#   'Date': ' Updated 31 Oct 2025, Added 15 Oct 2025'},
#  {'Title': ' Lovely 4 Bedroom Terraced Duplex ',
#   'Price': '₦ 125,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Lovely 4 Bedroom Terraced Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-5NSCY',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  {'Title': ' 4 Bedroom Detached Duplex With Bq ',
#   'Price': '₦ 165,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Detached Duplex With Bq',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-8NSNA',
#   'Date': ' Updated 31 Oct 2025, Added 23 Oct 2025'},
#  {'Title': ' 5 Bedroom Semi Detached Duplex With Bq ',
#   'Price': '₦ 480,000,000',
#   'Location': 'Victory Park Estate Osapa London Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': '5 Bedroom Semi Detached Duplex With Bq',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-victory-park-estate-osapa-london-lekki-lagos-4NSEE',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' Lovely 3 Bedroom Apartment ',
#   'Price': '₦ 300,000,000',
#   'Location': 'Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': 'Lovely 3 Bedroom Apartment',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/3-bedroom-house-for-sale-lekki-phase-1-lekki-lagos-1NSAG',
#   'Date': ' Updated 31 Oct 2025, Added 19 Oct 2025'},
#  {'Title': ' Stunning 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 160,000,000',
#   'Location': 'Lekki Conservation Chevron Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Stunning 4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-lekki-conservation-chevron-lekki-lagos-4NSEB',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' Stunning 5 Bedroom Detached Duplex ',
#   'Price': '₦ 770,000,000',
#   'Location': 'Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': 'Stunning 5 Bedroom Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-lekki-phase-1-lekki-lagos-6NSAF',
#   'Date': ' Updated 31 Oct 2025, Added 19 Oct 2025'},
#  {'Title': ' Lovely 4 Bedroom Terraced Duplex ',
#   'Price': '₦ 220,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds ',
#   'Type': 'Lovely 4 Bedroom Terraced Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-9NSCH',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  {'Title': ' Stunning 4 Bedroom Detached Duplex ',
#   'Price': '₦ 160,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Stunning 4 Bedroom Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-7NSCX',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  {'Title': ' 3 Bedroom Terrace Duplex ',
#   'Price': '₦ 110,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': '3 Bedroom Terrace Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/3-bedroom-house-for-sale-orchid-lekki-lagos-9NSEB',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' 2 Bedroom Apartment ',
#   'Price': ' ₦ 70,000,000 ',
#   'Location': 'Igbo Efon Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': '2 Bedroom Apartment',
#   'Agent': '\n               BLUEHEDGE REALTORS \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-igbo-efon-lekki-lagos-7NRAX',
#   'Date': 'Updated 31 Oct 2025, Added 10 Oct 2025'},
#  {'Title': ' Stunning 2 Bedroom Apartment ',
#   'Price': '₦ 300,000,000',
#   'Location': 'Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': 'Stunning 2 Bedroom Apartment',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-lekki-phase-1-lekki-lagos-7NQTS',
#   'Date': ' Updated 31 Oct 2025, Added 07 Oct 2025'},
#  {'Title': ' Luxury 4 Bedroom Terraced Duplex ',
#   'Price': '₦ 850,000,000',
#   'Location': 'Ikoyi Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Luxury 4 Bedroom Terraced Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ikoyi-lagos-8NRNE',
#   'Date': ' Updated 31 Oct 2025, Added 14 Oct 2025'},
#  {'Title': ' Stunning 4 Bedroom Terrace Duplex ',
#   'Price': '₦ 95,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Stunning 4 Bedroom Terrace Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-4NSEC',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' 5 Bedroom Detached Duplex ',
#   'Price': '₦ 850,000,000',
#   'Location': 'Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': '5 Bedroom Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-lekki-phase-1-lekki-lagos-1NSLE',
#   'Date': ' Updated 31 Oct 2025, Added 22 Oct 2025'},
#  {'Title': ' 3 Bedroom Apartment ',
#   'Price': '₦ 85,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': '3 Bedroom Apartment',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/3-bedroom-house-for-sale-orchid-lekki-lagos-0NSLE',
#   'Date': ' Updated 31 Oct 2025, Added 22 Oct 2025'},
#  {'Title': ' 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 155,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-4NSGH',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' Lovely 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 180,000,000',
#   'Location': 'Orchid Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Lovely 4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-orchid-lekki-lagos-1NSBC',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  {'Title': ' 5 Bedroom Detached Duplex ',
#   'Price': '₦ 1,000,000,000',
#   'Location': 'Lekki Phase 1 Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': '5 Bedroom Detached Duplex',
#   'Agent': '\n               ITJ REALTOR \n             ',
# ...
#   'Amenities': ' 1 Beds 1 Baths ',
#   'Type': '1 Bedroom Apartment',
#   'Agent': '\n               Ademeso olalekan \n             ',
#   'Link': '/property/1-bedroom-house-for-sale-mabushi-abuja-7MYXN',
#   'Date': ' Updated 31 Oct 2025, Added 21 May 2025'},
#  {'Title': ' 6 Bedroom Duplex ',
#   'Price': '₦ 290,000,000',
#   'Location': 'In A Serene And Secured Estate Life Camp Abuja',
#   'Amenities': ' 6 Beds 6 Baths ',
#   'Type': '6 Bedroom Duplex',
#   'Agent': '\n               Ademeso olalekan \n             ',
#   'Link': '/property/6-bedroom-house-for-sale-in-a-serene-and-secured-estate-life-camp-abuja-8MVJP',
#   'Date': ' Updated 31 Oct 2025, Added 28 Apr 2025'},
#  {'Title': ' 5 Bedroom Duplex ',
#   'Price': '₦ 1,000,000,000,000',
#   'Location': 'Guzape Abuja',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': '5 Bedroom Duplex',
#   'Agent': '\n               Ademeso olalekan \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-guzape-abuja-3MWEB',
#   'Date': ' Updated 31 Oct 2025, Added 03 May 2025'},
#  {'Title': ' Land Measuring 1,400sqm ',
#   'Price': '₦ 480,000,000',
#   'Location': 'Mabushi Mabushi Abuja',
#   'Amenities': ' ',
#   'Type': 'Land Measuring 1,400sqm',
#   'Agent': '\n               Ademeso olalekan \n             ',
#   'Link': '/property/land-for-sale-mabushi-mabushi-abuja-1MWXQ',
#   'Date': ' Updated 31 Oct 2025, Added 08 May 2025'},
#  {'Title': ' 3 Bedroom Detached Bungalow With 1 Bq ',
#   'Price': '₦ 135,000,000',
#   'Location': 'In An Estate Life Camp Abuja',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': '3 Bedroom Detached Bungalow With 1 Bq',
#   'Agent': '\n               Ademeso olalekan \n             ',
#   'Link': '/property/3-bedroom-house-for-sale-in-an-estate-life-camp-abuja-5NRTW',
#   'Date': ' Updated 31 Oct 2025, Added 16 Oct 2025'},
#  {'Title': ' 4 Bedroom Detached Duplex ',
#   'Price': '₦ 220,000,000',
#   'Location': 'Life Camp Abuja',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Detached Duplex',
#   'Agent': '\n               Ademeso olalekan \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-life-camp-abuja-8NGBX',
#   'Date': ' Updated 31 Oct 2025, Added 18 Jul 2025'},
#  {'Title': ' 4 Bedroom Terrace Duplex ',
#   'Price': '₦ 250,000,000',
#   'Location': 'Durumi Durumi Abuja',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Terrace Duplex',
#   'Agent': '\n               Ademeso olalekan \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-durumi-durumi-abuja-6NDGR',
#   'Date': ' Updated 31 Oct 2025, Added 25 Jun 2025'},
#  {'Title': ' 6 Bedroom Mansion ',
#   'Price': '₦ 850,000,000',
#   'Location': 'Gwarinpa Abuja',
#   'Amenities': ' 6 Beds 6 Baths ',
#   'Type': '6 Bedroom Mansion',
#   'Agent': '\n               Ademeso olalekan \n             ',
#   'Link': '/property/6-bedroom-house-for-sale-gwarinpa-abuja-3MWEU',
#   'Date': ' Updated 31 Oct 2025, Added 03 May 2025'},
#  {'Title': ' Mini Flat ',
#   'Price': '₦ 60,000,000',
#   'Location': 'Royal View Estate Agungi Lekki Lagos',
#   'Amenities': ' 1 Beds 2 Baths ',
#   'Type': 'Mini Flat',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/1-bedroom-flat-apartment-for-sale-royal-view-estate-agungi-lekki-lagos-5NSFS',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' 2 Bedroom Apartment ',
#   'Price': ' ₦ 220,000,000 ',
#   'Location': 'Ikate Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': '2 Bedroom Apartment',
#   'Agent': '\n               CEO Properties \n             ',
#   'Link': '/property/2-bedroom-flat-apartment-for-sale-ikate-lekki-lagos-7NQUB',
#   'Date': 'Updated 31 Oct 2025, Added 07 Oct 2025'},
#  {'Title': ' 2 Bedroom Apartment ',
#   'Price': '₦ 250,000,000',
#   'Location': 'Ikate Lekki Lagos',
#   'Amenities': ' 2 Beds 3 Baths ',
#   'Type': '2 Bedroom Apartment',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/2-bedroom-flat-apartment-for-sale-ikate-lekki-lagos-6NSKC',
#   'Date': ' Updated 31 Oct 2025, Added 22 Oct 2025'},
#  {'Title': ' Massive 4 Bedroom Terrace Duplex ',
#   'Price': '₦ 400,000,000',
#   'Location': 'Illasan Lekki Lagos',
#   'Amenities': ' 4 Beds 5 Baths ',
#   'Type': 'Massive 4 Bedroom Terrace Duplex',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/4-bedroom-flat-apartment-for-sale-illasan-lekki-lagos-4NSKE',
#   'Date': ' Updated 31 Oct 2025, Added 22 Oct 2025'},
#  {'Title': ' Block Of Flats ',
#   'Price': '₦ 120,000,000',
#   'Location': 'Ado Roundabout Ajah Lagos',
#   'Amenities': ' 1 Beds 2 Baths ',
#   'Type': 'Block Of Flats',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/1-bedroom-house-for-sale-ado-roundabout-ajah-lagos-5NSJP',
#   'Date': ' Updated 31 Oct 2025, Added 22 Oct 2025'},
#  {'Title': ' Standard 2 Bedroom Apartment ',
#   'Price': '₦ 140,000,000',
#   'Location': 'Illasan Lekki Lagos',
#   'Amenities': ' 2 Beds 3 Baths ',
#   'Type': 'Standard 2 Bedroom Apartment',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/2-bedroom-flat-apartment-for-sale-illasan-lekki-lagos-0NSKH',
#   'Date': ' Updated 31 Oct 2025, Added 22 Oct 2025'},
#  {'Title': ' Standard 3 Bedroom Apartment ',
#   'Price': '₦ 150,000,000',
#   'Location': 'Osapa London Lekki Lagos',
#   'Amenities': ' 4 Beds 5 Baths ',
#   'Type': 'Standard 3 Bedroom Apartment',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-osapa-london-lekki-lagos-8NSFV',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' 3 Bedroom Flat ',
#   'Price': '₦ 100,000,000',
#   'Location': 'Royal View Estate Agungi Lekki Lagos',
#   'Amenities': ' 3 Beds 4 Baths ',
#   'Type': '3 Bedroom Flat',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/3-bedroom-flat-apartment-for-sale-royal-view-estate-agungi-lekki-lagos-0NSFS',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' 4 Bedroom Detached Duplex With Bq ',
#   'Price': '₦ 90,000,000',
#   'Location': 'Thomas Estate Ajah Lagos',
#   'Amenities': ' 4 Beds 5 Baths ',
#   'Type': '4 Bedroom Detached Duplex With Bq',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-thomas-estate-ajah-lagos-1NTBC',
#   'Date': ' Updated 31 Oct 2025, Added 29 Oct 2025'},
#  {'Title': ' Massive 4 Bedroom Apartment ',
#   'Price': '₦ 200,000,000',
#   'Location': 'Igboefun Lekki Lagos',
#   'Amenities': ' 4 Beds 5 Baths ',
#   'Type': 'Massive 4 Bedroom Apartment',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-igboefun-lekki-lagos-7NSAB',
#   'Date': ' Updated 31 Oct 2025, Added 19 Oct 2025'},
#  {'Title': ' 2 Bedroom Flat ',
#   'Price': '₦ 80,000,000',
#   'Location': 'Royal View Estate Agungi Lekki Lagos',
#   'Amenities': ' 2 Beds 3 Baths ',
#   'Type': '2 Bedroom Flat',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/2-bedroom-flat-apartment-for-sale-royal-view-estate-agungi-lekki-lagos-5NSFT',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' 3 Bedroom Flat ',
#   'Price': ' ₦ 350,000/day ',
#   'Location': 'Eko Atlantic Victoria Island Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': '3 Bedroom Flat',
#   'Agent': '\n               TUPON LUXURY \n             ',
#   'Link': '/property/3-bedroom-flat-apartment-for-shortlet-eko-atlantic-victoria-island-lagos-7MVHE',
#   'Date': 'Updated 31 Oct 2025, Added 27 Apr 2025'},
#  {'Title': ' 7 Units Of Room And Parlour Self Contain ',
#   'Price': '₦ 50,000,000',
#   'Location': 'Harmony Estate Langbasa Ajah Lagos',
#   'Amenities': ' 1 Beds 2 Baths ',
#   'Type': '7 Units Of Room And Parlour Self Contain',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/1-bedroom-flat-apartment-for-sale-harmony-estate-langbasa-ajah-lagos-9NSFJ',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' Spacious 2 Bedroom Apartment ',
#   'Price': '₦ 120,000,000',
#   'Location': 'Igboefun Lekki Lagos',
#   'Amenities': ' 2 Beds 3 Baths ',
#   'Type': 'Spacious 2 Bedroom Apartment',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/2-bedroom-flat-apartment-for-sale-igboefun-lekki-lagos-4NSAB',
#   'Date': ' Updated 31 Oct 2025, Added 19 Oct 2025'},
#  {'Title': ' Standard Mini Flat ',
#   'Price': '₦ 65,000,000',
#   'Location': 'Igboefun Lekki Lagos',
#   'Amenities': ' 1 Beds 2 Baths ',
#   'Type': 'Standard Mini Flat',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/1-bedroom-flat-apartment-for-sale-igboefun-lekki-lagos-4NSAC',
#   'Date': ' Updated 31 Oct 2025, Added 19 Oct 2025'},
#  {'Title': ' 4 Bedroom Semi Detached Duplex ',
#   'Price': '₦ 270,000,000',
#   'Location': 'Osapa London Lekki Lagos',
#   'Amenities': ' 4 Beds 5 Baths ',
#   'Type': '4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-osapa-london-lekki-lagos-8NSFQ',
#   'Date': ' Updated 31 Oct 2025, Added 21 Oct 2025'},
#  {'Title': ' Newly Built Massive 2 Bedroom Apartment ',
#   'Price': '₦ 120,000,000',
#   'Location': 'Igboefun Lekki Lagos',
#   'Amenities': ' 2 Beds 3 Baths ',
#   'Type': 'Newly Built Massive 2 Bedroom Apartment',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/2-bedroom-house-for-sale-igboefun-lekki-lagos-0NSAC',
#   'Date': ' Updated 31 Oct 2025, Added 19 Oct 2025'},
#  {'Title': ' Standard 3 Bedroom Flat ',
#   'Price': '₦ 190,000,000',
#   'Location': 'Salem Lekki Lagos',
#   'Amenities': ' 3 Beds 4 Baths ',
#   'Type': 'Standard 3 Bedroom Flat',
#   'Agent': '\n               NNS MANAGEMENT \n             ',
#   'Link': '/property/3-bedroom-flat-apartment-for-sale-salem-lekki-lagos-6NSKJ',
#   'Date': ' Updated 31 Oct 2025, Added 22 Oct 2025'},
#  {'Title': ' 5 Bedroom Terraced Duplex ',
#   'Price': '₦ 175,000,000',
#   'Location': 'Opposite Oceanbay Estate, Orchid Road, Lekki Lagos',
#   'Amenities': ' 5 Beds 5 Baths ',
#   'Type': '5 Bedroom Terraced Duplex',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/5-bedroom-house-for-sale-opposite-oceanbay-estate-orchid-road-lekki-lagos-5NRJH',
#   'Date': ' Updated 31 Oct 2025, Added 13 Oct 2025'},
#  {'Title': ' 2 Bedroom Apartment ',
#   'Price': '₦ 90,000,000',
#   'Location': 'Garwood Court, Conservation Road, Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': '2 Bedroom Apartment',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/2-bedroom-flat-apartment-for-sale-garwood-court-conservation-road-lekki-lagos-5NSCP',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  {'Title': ' 2 Bedroom Apartment With Bq ',
#   'Price': '₦ 140,000,000',
#   'Location': 'Off Ologolo Road, Ologolo Lekki Lagos',
#   'Amenities': ' 2 Beds 2 Baths ',
#   'Type': '2 Bedroom Apartment With Bq',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/2-bedroom-flat-apartment-for-sale-off-ologolo-road-ologolo-lekki-lagos-1NRHL',
#   'Date': ' Updated 31 Oct 2025, Added 14 Oct 2025'},
#  {'Title': ' 4 Bedroom Terraced Duplex ',
#   'Price': '₦ 210,000,000',
#   'Location': 'Off Ologolo Road, Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Terraced Duplex',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-off-ologolo-road-lekki-lagos-3NRLV',
#   'Date': ' Updated 31 Oct 2025, Added 14 Oct 2025'},
#  {'Title': ' 4 Units Of 3 Bedroom Apartment ',
#   'Price': '₦ 290,000,000',
#   'Location': 'Thomas Estate Ajah Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': '4 Units Of 3 Bedroom Apartment',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/3-bedroom-flat-apartment-for-sale-thomas-estate-ajah-lagos-2NQYH',
#   'Date': ' Updated 31 Oct 2025, Added 09 Oct 2025'},
#  {'Title': ' 4 Bedroom Semi Detached Duplex ',
#   'Price': ' ₦ 180,000,000 ',
#   'Location': 'Ikota Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Semi Detached Duplex',
#   'Agent': '\n               Perfect Images \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-ikota-lekki-lagos-0NQNF',
#   'Date': 'Updated 31 Oct 2025, Added 06 Oct 2025'},
#  {'Title': ' 3 Bedroom Terrace Duplex ',
#   'Price': '₦ 140,000,000',
#   'Location': 'Cooplag Garden Estate Orchid Lekki Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': '3 Bedroom Terrace Duplex',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/3-bedroom-house-for-sale-cooplag-garden-estate-orchid-lekki-lagos-8NRZN',
#   'Date': ' Updated 31 Oct 2025, Added 18 Oct 2025'},
#  {'Title': ' Exquisite 4 Bedroom Detached Duplex ',
#   'Price': '₦ 125,000,000',
#   'Location': 'Van Daniel Estate, Orchid Road, Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': 'Exquisite 4 Bedroom Detached Duplex',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-van-daniel-estate-orchid-road-lekki-lagos-8NRJU',
#   'Date': ' Updated 31 Oct 2025, Added 13 Oct 2025'},
#  {'Title': ' 4 Bedroom Terrace Duplex ',
#   'Price': '₦ 120,000,000',
#   'Location': 'Off Mobil Road Ilaje Ajah Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Terrace Duplex',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-off-mobil-road-ilaje-ajah-lagos-6NRBB',
#   'Date': ' Updated 31 Oct 2025, Added 10 Oct 2025'},
#  {'Title': ' New 1 Bedroom Apartment With Swimming Pool ',
#   'Price': '₦ 75,000,000',
#   'Location': 'Off Spg Road, Ologolo Lekki Lagos',
#   'Amenities': ' 1 Beds 1 Baths ',
#   'Type': 'New 1 Bedroom Apartment With Swimming Pool',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/1-bedroom-flat-apartment-for-sale-off-spg-road-ologolo-lekki-lagos-0NRTV',
#   'Date': ' Updated 31 Oct 2025, Added 16 Oct 2025'},
#  {'Title': ' 4 Bedroom Fully Detached Smart Home With Bq ',
#   'Price': '₦ 210,000,000',
#   'Location': 'Buena Vista Estate, Orchid Road Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Fully Detached Smart Home With Bq',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-buena-vista-estate-orchid-road-lekki-lagos-8NRBQ',
#   'Date': ' Updated 31 Oct 2025, Added 10 Oct 2025'},
#  {'Title': ' 4 Bedroom Terraced Duplex ',
#   'Price': '₦ 120,000,000',
#   'Location': 'Gra Ikota Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Terraced Duplex',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-gra-ikota-lekki-lagos-0NRUE',
#   'Date': ' Updated 31 Oct 2025, Added 16 Oct 2025'},
#  {'Title': ' 4 Bedroom Terraced Duplex ',
#   'Price': '₦ 210,000,000',
#   'Location': 'Spg Road Ologolo Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Terraced Duplex',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-spg-road-ologolo-lekki-lagos-6NRZN',
#   'Date': ' Updated 31 Oct 2025, Added 18 Oct 2025'},
#  {'Title': ' 4 Bedroom Detached Duplex ',
#   'Price': '₦ 480,000,000',
#   'Location': 'Northern Foreshore, Chevron Drive, Lekki Lagos',
#   'Amenities': ' 4 Beds 4 Baths ',
#   'Type': '4 Bedroom Detached Duplex',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/4-bedroom-house-for-sale-northern-foreshore-chevron-drive-lekki-lagos-6NRUH',
#   'Date': ' Updated 31 Oct 2025, Added 16 Oct 2025'},
#  {'Title': ' 3 Bedroom Apartment ',
#   'Price': '₦ 100,000,000',
#   'Location': 'Lekki Scheme 2 Estate, Ogombo Ajah Lagos',
#   'Amenities': ' 3 Beds 3 Baths ',
#   'Type': '3 Bedroom Apartment',
#   'Agent': '\n               17Three Digital \n             ',
#   'Link': '/property/3-bedroom-flat-apartment-for-sale-lekki-scheme-2-estate-ogombo-ajah-lagos-8NSCN',
#   'Date': ' Updated 31 Oct 2025, Added 20 Oct 2025'},
#  ...]

# %%
Raw_Properties = pd.DataFrame(all_properties)

# %%
Raw_Properties
# Out:
#                                                   Title            Price  \
# 0      Brand New Smart Home With Parking For 10 Cars...   ₦ 600,000,000
# 1                      5 Bedroom Fully Detached Duplex     ₦ 980,000,000
# 2                    5 Bedroom Detached Duplex With Bq     ₦ 420,000,000
# 3                               24 Room Hotel Building     ₦ 550,000,000
# 4                                       1 Bedroom Flat      ₦ 95,000,000
# ...                                                 ...              ...
# 5033      4 Bedroom Duplex + 2 Units Of 2 Bedroom Flat     ₦ 230,000,000
# 5034                                4 Bedroom Bungalow      ₦ 40,000,000
# 5035                      Warehouse On 880 Sqm Of Land     ₦ 495,000,000
# 5036                         Land Measureing 1,156 Sqm   ₦ 1,500,000,000
# 5037                          Land Measuring 1,971 Sqm   ₦ 1,400,000,000
#
#                                          Location         Amenities  \
# 0           Omole Phase 1 Ikeja Lagos Ikeja Lagos   5 Beds 6 Baths
# 1                               Ikate Lekki Lagos   5 Beds 6 Baths
# 2                           Megamound Lekki Lagos   5 Beds 5 Baths
# 3              Unity Estate Egbeda Alimosho Lagos
# 4                               Ikate Lekki Lagos           1 Beds
# ...                                           ...               ...
# 5033       Aqua View Estate Ogudu Gra Ogudu Lagos
# 5034               Macaulay Igbogbo Ikorodu Lagos   4 Beds 4 Baths
# 5035                        Agidingbi Ikeja Lagos
# 5036  Hakeem Dickson Street Victoria Island Lagos
# 5037   Herbert Macaulay Way Ikeja Gra Ikeja Lagos
#
#                                                    Type  \
# 0     Brand New Smart Home With Parking For 10 Cars ...
# 1                       5 Bedroom Fully Detached Duplex
# 2                     5 Bedroom Detached Duplex With Bq
# 3                                24 Room Hotel Building
# 4                                        1 Bedroom Flat
# ...                                                 ...
# 5033       4 Bedroom Duplex + 2 Units Of 2 Bedroom Flat
# 5034                                 4 Bedroom Bungalow
# 5035                       Warehouse On 880 Sqm Of Land
# 5036                          Land Measureing 1,156 Sqm
# 5037                           Land Measuring 1,971 Sqm
#
#                                                   Agent  \
# 0        \n               Loyalty homes \n
# 1          \n               Joe Etoniru \n
# 2     \n               BLUEHEDGE REALTORS \n        ...
# 3           \n               Ubosi Eleh \n
# 4           \n               Ubosi Eleh \n
# ...                                                 ...
# 5033  \n               DE-BASH PROPERTY \n
# 5034  \n               DE-BASH PROPERTY \n
# 5035  \n               DE-BASH PROPERTY \n
# 5036  \n               DE-BASH PROPERTY \n
# 5037  \n               DE-BASH PROPERTY \n
#
#                                                    Link  \
# 0     /property/5-bedroom-house-for-sale-omole-phase...
# 1     /property/5-bedroom-house-for-sale-ikate-lekki...
# 2     /property/5-bedroom-house-for-sale-megamound-l...
# 3     /property/commercial-property-for-sale-unity-e...
# 4     /property/1-bedroom-flat-apartment-for-sale-ik...
# ...                                                 ...
# 5033  /property/house-for-sale-aqua-view-estate-ogud...
# 5034  /property/4-bedroom-flat-apartment-for-sale-ma...
# 5035  /property/commercial-property-for-sale-agiding...
# 5036  /property/land-for-sale-hakeem-dickson-street-...
# 5037  /property/land-for-sale-herbert-macaulay-way-i...
#
#                                          Date
# 0      Updated 31 Oct 2025, Added 15 May 2025
# 1      Updated 01 Nov 2025, Added 09 Oct 2025
# 2      Updated 01 Nov 2025, Added 22 Nov 2024
# 3      Updated 01 Nov 2025, Added 17 Jul 2025
# 4      Updated 01 Nov 2025, Added 17 Jul 2025
# ...                                       ...
# 5033   Updated 01 Nov 2025, Added 28 Aug 2025
# 5034   Updated 01 Nov 2025, Added 10 Sep 2025
# 5035   Updated 01 Nov 2025, Added 10 Sep 2025
# 5036   Updated 01 Nov 2025, Added 20 Sep 2025
# 5037   Updated 01 Nov 2025, Added 20 Sep 2025
#
# [5038 rows x 8 columns]

# %%
Raw_Properties.to_csv("../Data/Raw Data from PropertyPro.csv", index = False)
